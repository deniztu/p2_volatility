# %%
import scipy.optimize as optimize
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 

# allows rotation of plots
# %matplotlib notebook

# %%
# load data
df = pd.read_csv('3D_data.csv')
df.head()
# Out:
#    Unnamed: 0         X         Y         Z
# 0           0  0.222454  0.009301 -0.088070
# 1           1  0.231062  0.197496  0.351979
# 2           2  0.425113  0.433398  0.716404
# 3           3  0.513050  0.563022  1.154526
# 4           4  0.530569  0.649272  1.742551

# %%
A = np.vstack([df.X, df.Y, df.Z])
x = np.transpose(A[:2,:])
y = A[2,:]

def func(data, a, b):
    return data[:,0]*data[:,1]*a + b

guess = (1,1)
params, pcov = optimize.curve_fit(func, x, y, guess)
print(params)
# Out:
# [ 1.76347455e-01 -2.06733963e-10]

# %%
pred = func(x, params[0], params[1])

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

ax.scatter(df.X,df.Y,pred)
ax.scatter(df.X,df.Y,df.Z)
# Out:
# <img src="data:image/png;base64,..." width="640">
