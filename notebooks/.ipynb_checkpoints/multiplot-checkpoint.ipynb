# %%
notebook merges single plots to a grid (multiplot)
# Out:
# UsageError: unrecognized arguments: single plots to a grid (multiplot)

# %%
#import libraries
import cv2
import os
from matplotlib import pyplot as plt

# %%
#move up in directory
os.chdir('../')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\deniz\\Desktop\\PhD\\p1_generalization'

# %% [markdown]
# # Figure 2

# %%
# reading images
img = cv2.imread(os.path.join('plots','figure_2_A.png'))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
image1 = img

img = cv2.imread(os.path.join('plots','figure_2_B.png'))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
image2 = img

img = cv2.imread(os.path.join('plots','figure_2_C.png'))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
image3 = img

# img = cv2.imread(os.path.join('plots','figure_2_D.png'))
# img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# image4 = img

images = [image1, image2, image3]

# %%
fig = plt.figure(figsize=(20, 15))
#plt.subplots_adjust(wspace = 1, hspace = 0.1)
for i, label in enumerate(('a', 'b', 'c')):
    ax = fig.add_subplot(1,3,i+1)
    ax.imshow(images[i])
    ax.axis('off')
    ax.text(0, 1, label, transform=ax.transAxes,
      fontsize=40, fontweight='bold', va='top', ha='right')

fig.tight_layout()
plt.savefig('../p1_generalization/plots/Figure_2_labels_test.svg', dpi = 600)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2320\2910014523.py in <module>
#       3 for i, label in enumerate(('a', 'b', 'c')):
#       4     ax = fig.add_subplot(1,3,i+1)
# ----> 5     ax.imshow(images[i])
#       6     ax.axis('off')
#       7     ax.text(0, 1, label, transform=ax.transAxes,
#
# ~\AppData\Local\anaconda3\envs\rnn\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     457                 "parameter will become keyword-only %(removal)s.",
#     458                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459         return func(*args, **kwargs)
#     460
#     461     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# ~\AppData\Local\anaconda3\envs\rnn\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1412     def inner(ax, *args, data=None, **kwargs):
#    1413         if data is None:
# -> 1414             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1415
#    1416         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\AppData\Local\anaconda3\envs\rnn\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5485                               **kwargs)
#    5486
# -> 5487         im.set_data(X)
#    5488         im.set_alpha(alpha)
#    5489         if im.get_clip_path() is None:
#
# ~\AppData\Local\anaconda3\envs\rnn\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     705                 not np.can_cast(self._A.dtype, float, "same_kind")):
#     706             raise TypeError("Image data of dtype {} cannot be converted to "
# --> 707                             "float".format(self._A.dtype))
#     708
#     709         if self._A.ndim == 3 and self._A.shape[-1] == 1:
#
# TypeError: Image data of dtype object cannot be converted to float

# %% [markdown]
# # Figure 5

# %%
# reading images
img = cv2.imread(os.path.join('plots','figure_5_D.png'))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
image1 = img

img = cv2.imread(os.path.join('plots','figure_5_E.png'))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
image2 = img

img = cv2.imread(os.path.join('plots','fig_5_F.png'))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
image3 = img

images = [image1, image2, image3]

# %%
fig = plt.figure(figsize=(20, 15))
for i, label in enumerate(('A', 'B', 'C')):
    ax = fig.add_subplot(1,3,i+1)
    ax.imshow(images[i])
    ax.axis('off')

fig.tight_layout()
plt.savefig('../p1_generalization/plots/Figure_5.jpeg', dpi = 600)
plt.show()

# %% [markdown]
# # Figure 6

# %%
# reading images
img = cv2.imread(os.path.join('plots','fig_6_A.png'))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
image1 = img

img = cv2.imread(os.path.join('plots','fig_6_B.png'))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
image2 = img

images = [image1, image2]

# %%
fig = plt.figure(figsize=(20, 15))
#plt.subplots_adjust(wspace = 1, hspace = 0.1)
for i, label in enumerate(('A', 'B')):
    ax = fig.add_subplot(1,2,i+1)
    ax.imshow(images[i])
    ax.axis('off')
    ax.text(0, 1, label, transform=ax.transAxes,
      fontsize=40, fontweight='bold', va='top', ha='right')

fig.tight_layout()
plt.savefig('../p1_generalization/plots/Figure_6.png', dpi = 600)
plt.show()

# %% [markdown]
# # Supplemental Figure 3

# %%
# reading images

img = cv2.imread(os.path.join('plots','3d_plot_id_0_walk_1.png'))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
image1 = img

img = cv2.imread(os.path.join('plots','3d_plot_id_0_walk_1.png'))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
image2 = img

img = cv2.imread(os.path.join('plots','3d_plot_id_0_walk_1.png'))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
image3 = img

images = [image1, image2, image3]

# %%
fig = plt.figure(figsize=(20, 15))

#plt.subplots_adjust(wspace = 1, hspace = 0.01)
for i, label in enumerate(('A', 'B', 'C')):
    ax = fig.add_subplot(3,1,i+1)
    ax.imshow(images[i])
    ax.axis('off')
#    ax.text(0, 1, label, transform=ax.transAxes,
#      fontsize=40, fontweight='bold', va='top', ha='right')
#plt.subplots_adjust(left=0.5, bottom=0, right=1, top=0.1, wspace=0, hspace=0)
fig.tight_layout()
plt.savefig('../p1_generalization/plots/supplemental_figure_3.png', dpi = 600, bbox_inches='tight')
plt.show()
